# %% [markdown]
# # InvoiceGuard AI — End-to-End
# This notebook documents the same training pipeline used by `src/train.py`. Run the script for reproducibility, then use this notebook for presentation/exploration.

# %%
# !python scripts/generate_demo.py
# !python -m src.train --source demo

# %%
import json, pandas as pd
print(json.load(open('reports/data_audit.json'))['usable_rows'])
print(pd.read_csv('reports/model_comparison.csv'))
print(json.load(open('reports/test_metrics.json')))

# %% [markdown]
# ## Important
# For the final thesis/report, replace the demo run with the official Kaggle dataset using `python scripts/download_data.py` and `python -m src.train --source kaggle`. Never report demo metrics as real-world results.
